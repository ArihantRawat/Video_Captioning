# %%
import csv

# %%
rowData = []

# %%
with open('dataset/MSR Video Description Corpus.csv', 'r',encoding="utf8") as file:
    reader = csv.reader(file)
    for row in reader:
        tempRow = []
        if len(row)>0 and row[6]=='English':
            tempRow.append(row[0]+'_'+row[1]+'_'+row[2]+'.avi')
            tempRow.append(row[7])
        if len(tempRow)==2:
            rowData.append(tempRow)
# Out:
# man is bowling.'], ['lc9bA-hvqHU_1_6', 'A guy is playing the bowling .'], ['lc9bA-hvqHU_1_6', 'Flying Eagle Bowling Shot'], ['lc9bA-hvqHU_1_6', 'A man playing very well'], ['lc9bA-hvqHU_1_6', 'A bowler hits two duckpins on two sides with one throw.'], ['lc9bA-hvqHU_1_6', 'The man made an amazing bowling shot.'], ['lc9bA-hvqHU_1_6', 'A man does a bowling trick shot.'], ['lc9bA-hvqHU_1_6', 'A man is playing.'], ['lc9bA-hvqHU_1_6', 'the man was flying'], ['lc9bA-hvqHU_1_6', 'A man is bowling.'], ['lc9bA-hvqHU_1_6', 'A MAN IS PLAYING BOWLING GAME HITS MANY BOTTLES.'], ['2YhDTpzxd3c_166_170', 'A man is climbing up a knotted rope suspended from the ceiling, when the scene flashes to the same man splashing water on his face from an outdoor container.'], ['2YhDTpzxd3c_166_170', 'A man climbs a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope that is suspended from what looks like the ceiling of a warehouse.'], ['2YhDTpzxd3c_166_170', 'A man is climbing by a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man climbs a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'the man shimmied up the rope.'], ['2YhDTpzxd3c_166_170', 'The man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man climbs a rope.'], ['2YhDTpzxd3c_166_170', 'The man climbed up a rope.'], ['2YhDTpzxd3c_166_170', 'a man climbing a rope'], ['2YhDTpzxd3c_166_170', 'A man i climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A soldier is taking training'], ['2YhDTpzxd3c_166_170', 'the person is doing the something'], ['2YhDTpzxd3c_166_170', 'a man climbing with a rope.'], ['2YhDTpzxd3c_166_170', 'A man climbs up on a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing a rope.'], ['2YhDTpzxd3c_166_170', 'A man is climbing up a rope.'], ['2YhDTpzxd3c_166_170', 'A soldier is climbing through a ladder.'], ['2YhDTpzxd3c_166_170', 'a soldier is climbing with rope'], ['2YhDTpzxd3c_166_170', 'ACTOR VIJAY IS CLIMBING IN A ROPE.'], ['2YhDTpzxd3c_166_170', 'Army training.'], ['2YhDTpzxd3c_166_170', 'The man is climbing up the rope.'], ['2YhDTpzxd3c_166_170', 'The man pulled himself up the rope.'], ['2YhDTpzxd3c_166_170', 'A MAN IS GETUP THE ROPE.'], ['2YhDTpzxd3c_166_170', 'A MAN IS HANGED ON A ROPE'], ['2YhDTpzxd3c_166_170', 'A man is climbing with thick tag.'], ['6t0BpjwYKco_230_240', 'A woman is cutting into the fatty areas of a pork chop.'], ['6t0BpjwYKco_230_240', 'A woman cuts a pork chop.'], ['6t0BpjwYKco_230_240', 'A woman cuts slots into a pork chop.'], ['6t0BpjwYKco_230_240', 'A woman is putting cuts into a piece of meat.'], ['6t0BpjwYKco_230_240', 'A woman is cutting meat.'], ['6t0BpjwYKco_230_240', 'A woman is cutting small slices into a piece of pork.'], ['6t0BpjwYKco_230_240', 'A woman with a knife is poking meat.'], ['6t0BpjwYKco_230_240', 'A woman makes small cuts in a piece of meat.'], ['6t0BpjwYKco_230_240', 'A woman is scoring meat.'], ['6t0BpjwYKco_230_240', 'A person is slicing meat.'], ['6t0BpjwYKco_230_240', 'A woman is cutting a piece of meat.'], ['6t0BpjwYKco_230_240', 'A woman makes small cuts along the edges and on the surface of a slab of pork meat on both sides.'], ['6t0BpjwYKco_230_240', 'A woman makes cuts along the sides of a pork loin.'], ['6t0BpjwYKco_230_240', 'The lady made cuts into the meat.'], ['6t0BpjwYKco_230_240', 'The woman is making little slits into the pork chop.'], ['6t0BpjwYKco_230_240', 'A woman makes fine cuts in some meat.'], ['6t0BpjwYKco_230_240', 'The lady sliced notches  ...

# %%
#print(rowData)
# Out:
# []

# %%
fields = ['VideoID', 'Description']   

# writing to csv file 
with open('dataset/MSVD_description_cfile.csv', 'w',encoding="utf8") as csvfile: 
    csvwriter = csv.writer(csvfile) 
    csvwriter.writerow(fields) 
    csvwriter.writerows(rowData)
print("done")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-36-6db53b1e9331> in <module>
#       5     csvwriter = csv.writer(csvfile)
#       6     csvwriter.writerow(fields)
# ----> 7     csvwriter.writerows(rowData)
#       8 print("done")
#
# ~\Anaconda3\envs\nlp_course\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\ufeff' in position 34: character maps to <undefined>
